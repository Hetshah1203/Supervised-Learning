# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("/content/Book1.csv")
df
# Out:
#    Petal Width  Petal Length
# 0          0.2           1.4
# 1          0.3           1.3
# 2          1.3           4.5
# 3          1.5           4.7
# 4          2.0           6.3
# 5          2.2           6.5

# %%
from sklearn.model_selection import train_test_split
train,test=train_test_split(df,test_size=0.2)
x_train=train.drop('Petal Length',axis=1)
y_train=train['Petal Length']

x_test=test.drop('Petal Length',axis=1)
y_test=test['Petal Length']

# %%
from sklearn import neighbors
from sklearn.metrics import mean_squared_error
from math import sqrt

model = neighbors.KNeighborsRegressor(n_neighbors=3)
model.fit(x_train,y_train)
pred = model.predict(x_test)
error = sqrt(mean_squared_error(y_test,pred))
error
# Out:
# 1.75894539110482

# %%
#predict for petal width = 1.4
pred = model.predict([[1.4]])
pred
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# array([5.16666667])
